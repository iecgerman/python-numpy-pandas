# %% [markdown]
# <a href="https://colab.research.google.com/github/iecgerman/python-numpy-pandas/blob/master/clase11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Visualización y Almacenamiento de Datos con NumPy

import numpy as np

sales = np.random.randint(100, 301, size=12)
print(sales)
np.save('sales.npy', sales)
# Out:
# [237 242 132 162 205 215 247 211 173 193 196 159]

# %%
loaded_sales = np.load('sales.npy')
print(loaded_sales)
# Out:
# [237 242 132 162 205 215 247 211 173 193 196 159]

# %%
np.savetxt('sales.csv', sales, delimiter=',')

# %%
loaded_sales_csv = np.loadtxt('sales.csv', delimiter=',')
print(loaded_sales_csv)
# Out:
# [237. 242. 132. 162. 205. 215. 247. 211. 173. 193. 196. 159.]

# %%
import numpy as np
import matplotlib.pyplot as plt

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

plt.figure(figsize=(10,5))
plt.bar(months,sales, color= 'b', label='ventas generadas')
plt.title('Ventas por Mes')
plt.xlabel('Meses')
plt.ylabel('Ventas')
plt.xticks(rotation = 45)
plt.show()
